# %%
# !pip install opencv_python_headless==4.5.2.54 streamlit==0.82.0 mediapipe==0.8.4.2 numpy==1.18.5 Pillow==8.2.0
# Out:
# Collecting opencv_python_headless==4.5.2.54
#   Using cached opencv_python_headless-4.5.2.54-cp37-cp37m-win_amd64.whl (34.6 MB)
# Collecting streamlit==0.82.0
#   Using cached streamlit-0.82.0-py2.py3-none-any.whl (8.2 MB)
# Collecting mediapipe==0.8.4.2
#   Using cached mediapipe-0.8.4.2-cp37-cp37m-win_amd64.whl (52.0 MB)
# Collecting numpy==1.18.5
#   Using cached numpy-1.18.5-cp37-cp37m-win_amd64.whl (12.7 MB)
# Requirement already satisfied: Pillow==8.2.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (8.2.0)
# Collecting gitpython
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: toml in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (0.10.2)
# Requirement already satisfied: packaging in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (21.3)
# Collecting pyarrow
#   Using cached pyarrow-8.0.0-cp37-cp37m-win_amd64.whl (17.8 MB)
# Requirement already satisfied: cachetools>=4.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (5.0.0)
# Requirement already satisfied: python-dateutil in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (2.8.2)
# Requirement already satisfied: validators in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (0.20.0)
# Collecting pandas>=0.21.0
#   Using cached pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# Requirement already satisfied: blinker in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (1.4)
# Requirement already satisfied: watchdog in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (2.1.9)
# Requirement already satisfied: requests in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (2.27.1)
# Collecting tzlocal
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# Collecting base58
#   Using cached base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting click<8.0,>=7.0
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting astor
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (3.20.1)
# Collecting pydeck>=0.1.dev5
#   Using cached pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# Collecting altair>=3.2.0
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: tornado>=5.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from streamlit==0.82.0) (6.1)
# Requirement already satisfied: opencv-contrib-python in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from mediapipe==0.8.4.2) (4.5.5.64)
# Requirement already satisfied: six in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from mediapipe==0.8.4.2) (1.15.0)
# Requirement already satisfied: wheel in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from mediapipe==0.8.4.2) (0.37.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from mediapipe==0.8.4.2) (21.4.0)
# Requirement already satisfied: absl-py in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from mediapipe==0.8.4.2) (0.15.0)
# Requirement already satisfied: entrypoints in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from altair>=3.2.0->streamlit==0.82.0) (0.4)
# Requirement already satisfied: jinja2 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from altair>=3.2.0->streamlit==0.82.0) (3.0.3)
# Requirement already satisfied: toolz in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from altair>=3.2.0->streamlit==0.82.0) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from altair>=3.2.0->streamlit==0.82.0) (4.4.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from pandas>=0.21.0->streamlit==0.82.0) (2022.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from pydeck>=0.1.dev5->streamlit==0.82.0) (7.6.5)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from pydeck>=0.1.dev5->streamlit==0.82.0) (6.9.0)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from pydeck>=0.1.dev5->streamlit==0.82.0) (5.1.1)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from gitpython->streamlit==0.82.0) (3.7.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from packaging->streamlit==0.82.0) (3.0.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from requests->streamlit==0.82.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from requests->streamlit==0.82.0) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from requests->streamlit==0.82.0) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from requests->streamlit==0.82.0) (2021.10.8)
# Collecting pytz-deprecation-shim
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tzdata in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from tzlocal->streamlit==0.82.0) (2022.1)
# Collecting backports.zoneinfo
#   Using cached backports.zoneinfo-0.2.1-cp37-cp37m-win_amd64.whl (38 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from validators->streamlit==0.82.0) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->streamlit==0.82.0) (5.0.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (7.31.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (1.5.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (7.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (1.5.4)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (0.1.3)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (1.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jinja2->altair>=3.2.0->streamlit==0.82.0) (2.0.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.82.0) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.82.0) (5.4.0)
# Requirement already satisfied: importlib-metadata in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==0.82.0) (4.10.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=3.0->altair>=3.2.0->streamlit==0.82.0) (3.7.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (62.1.0)
# Requirement already satisfied: pickleshare in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (0.7.5)
# Requirement already satisfied: pygments in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (0.18.1)
# Requirement already satisfied: colorama in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (3.0.27)
# Requirement already satisfied: backcall in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (0.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (4.9.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (22.3.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (0.8.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (303)
# Requirement already satisfied: nbconvert in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (6.4.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit==0.82.0) (0.2.5)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (21.2.0)
# Requirement already satisfied: defusedxml in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.5.10)
# Requirement already satisfied: bleach in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (4.1.0)
# Requirement already satisfied: testpath in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.8.4)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit==0.82.0) (2.21)
# Installing collected packages: numpy, gitdb, click, base58, backports.zoneinfo, astor, pytz-deprecation-shim, pyarrow, pandas, opencv_python_headless, gitpython, tzlocal, mediapipe, altair, pydeck, streamlit
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# WARNING: Ignoring invalid distribution -illow (c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\muzamil khattak\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\~umpy\\.libs\\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -illow (c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\muzamil khattak\appdata\local\programs\python\python37\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\Muzamil Khattak\AppData\Local\Programs\Python\Python37\python.exe -m pip install --upgrade pip' command.

# %%
#Modified by Augmented Startups 2021
#Face Landmark User Interface with StreamLit
#Watch Computer Vision Tutorials at www.augmentedstartups.info/YouTube
import streamlit as st
import mediapipe as mp
import cv2
import numpy as np
import tempfile
import time
from PIL import Image

mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

DEMO_VIDEO = 'demo.mp4'
DEMO_IMAGE = 'demo.jpg'

st.title('Face Mesh Application using MediaPipe')

st.markdown(
    """
    <style>
    [data-testid="stSidebar"][aria-expanded="true"] > div:first-child {
        width: 350px;
    }
    [data-testid="stSidebar"][aria-expanded="false"] > div:first-child {
        width: 350px;
        margin-left: -350px;
    }
    </style>
    """,
    unsafe_allow_html=True,
)

st.sidebar.title('Face Mesh Application using MediaPipe')
st.sidebar.subheader('Parameters')

@st.cache()
def image_resize(image, width=None, height=None, inter=cv2.INTER_AREA):
    # initialize the dimensions of the image to be resized and
    # grab the image size
    dim = None
    (h, w) = image.shape[:2]

    # if both the width and height are None, then return the
    # original image
    if width is None and height is None:
        return image

    # check to see if the width is None
    if width is None:
        # calculate the ratio of the height and construct the
        # dimensions
        r = height / float(h)
        dim = (int(w * r), height)

    # otherwise, the height is None
    else:
        # calculate the ratio of the width and construct the
        # dimensions
        r = width / float(w)
        dim = (width, int(h * r))

    # resize the image
    resized = cv2.resize(image, dim, interpolation=inter)

    # return the resized image
    return resized

app_mode = st.sidebar.selectbox('Choose the App mode',
['About App','Run on Image','Run on Video']
)

if app_mode =='About App':
    st.markdown('In this application we are using **MediaPipe** for creating a Face Mesh. **StreamLit** is to create the Web Graphical User Interface (GUI) ')
    st.markdown(
    """
    <style>
    [data-testid="stSidebar"][aria-expanded="true"] > div:first-child {
        width: 400px;
    }
    [data-testid="stSidebar"][aria-expanded="false"] > div:first-child {
        width: 400px;
        margin-left: -400px;
    }
    </style>
    """,
    unsafe_allow_html=True,
    )
    st.video('https://www.youtube.com/watch?v=FMaNNXgB_5c&ab_channel=AugmentedStartups')

    st.markdown('''
          # About Me \n 
            Hey this is ** Ritesh Kanjee ** from **Augmented Startups**. \n
           
            If you are interested in building more Computer Vision apps like this one then visit the **Vision Store** at
            www.augmentedstartups.info/visionstore \n
            
            Also check us out on Social Media
            - [YouTube](https://augmentedstartups.info/YouTube)
            - [LinkedIn](https://augmentedstartups.info/LinkedIn)
            - [Facebook](https://augmentedstartups.info/Facebook)
            - [Discord](https://augmentedstartups.info/Discord)
        
            If you are feeling generous you can buy me a **cup of  coffee ** from [HERE](https://augmentedstartups.info/ByMeACoffee)
             
            ''')
elif app_mode =='Run on Video':

    st.set_option('deprecation.showfileUploaderEncoding', False)

    use_webcam = st.sidebar.button('Use Webcam')
    record = st.sidebar.checkbox("Record Video")
    if record:
        st.checkbox("Recording", value=True)

    st.sidebar.markdown('---')
    st.markdown(
    """
    <style>
    [data-testid="stSidebar"][aria-expanded="true"] > div:first-child {
        width: 400px;
    }
    [data-testid="stSidebar"][aria-expanded="false"] > div:first-child {
        width: 400px;
        margin-left: -400px;
    }
    </style>
    """,
    unsafe_allow_html=True,
        )
    # max faces
    max_faces = st.sidebar.number_input('Maximum Number of Faces', value=1, min_value=1)
    st.sidebar.markdown('---')
    detection_confidence = st.sidebar.slider('Min Detection Confidence', min_value =0.0,max_value = 1.0,value = 0.5)
    tracking_confidence = st.sidebar.slider('Min Tracking Confidence', min_value = 0.0,max_value = 1.0,value = 0.5)

    st.sidebar.markdown('---')

    st.markdown(' ## Output')

    stframe = st.empty()
    video_file_buffer = st.sidebar.file_uploader("Upload a video", type=[ "mp4", "mov",'avi','asf', 'm4v' ])
    tfflie = tempfile.NamedTemporaryFile(delete=False)


    if not video_file_buffer:
        if use_webcam:
            vid = cv2.VideoCapture(0)
        else:
            vid = cv2.VideoCapture(DEMO_VIDEO)
            tfflie.name = DEMO_VIDEO
    
    else:
        tfflie.write(video_file_buffer.read())
        vid = cv2.VideoCapture(tfflie.name)

    width = int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps_input = int(vid.get(cv2.CAP_PROP_FPS))

    #codec = cv2.VideoWriter_fourcc(*FLAGS.output_format)
    codec = cv2.VideoWriter_fourcc('V','P','0','9')
    out = cv2.VideoWriter('output1.mp4', codec, fps_input, (width, height))

    st.sidebar.text('Input Video')
    st.sidebar.video(tfflie.name)
    fps = 0
    i = 0
    drawing_spec = mp_drawing.DrawingSpec(thickness=2, circle_radius=2)

    kpi1, kpi2, kpi3 = st.beta_columns(3)

    with kpi1:
        st.markdown("**FrameRate**")
        kpi1_text = st.markdown("0")

    with kpi2:
        st.markdown("**Detected Faces**")
        kpi2_text = st.markdown("0")

    with kpi3:
        st.markdown("**Image Width**")
        kpi3_text = st.markdown("0")

    st.markdown("<hr/>", unsafe_allow_html=True)

    with mp_face_mesh.FaceMesh(
    min_detection_confidence=detection_confidence,
    min_tracking_confidence=tracking_confidence , 
    max_num_faces = max_faces) as face_mesh:
        prevTime = 0

        while vid.isOpened():
            i +=1
            ret, frame = vid.read()
            if not ret:
                continue

            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = face_mesh.process(frame)

            frame.flags.writeable = True
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)

            face_count = 0
            if results.multi_face_landmarks:
                for face_landmarks in results.multi_face_landmarks:
                    face_count += 1
                    mp_drawing.draw_landmarks(
                    image = frame,
                    landmark_list=face_landmarks,
                    connections=mp_face_mesh.FACE_CONNECTIONS,
                    landmark_drawing_spec=drawing_spec,
                    connection_drawing_spec=drawing_spec)
            currTime = time.time()
            fps = 1 / (currTime - prevTime)
            prevTime = currTime
            if record:
                #st.checkbox("Recording", value=True)
                out.write(frame)
            #Dashboard
            kpi1_text.write(f"<h1 style='text-align: center; color: red;'>{int(fps)}</h1>", unsafe_allow_html=True)
            kpi2_text.write(f"<h1 style='text-align: center; color: red;'>{face_count}</h1>", unsafe_allow_html=True)
            kpi3_text.write(f"<h1 style='text-align: center; color: red;'>{width}</h1>", unsafe_allow_html=True)

            frame = cv2.resize(frame,(0,0),fx = 0.8 , fy = 0.8)
            frame = image_resize(image = frame, width = 640)
            stframe.image(frame,channels = 'BGR',use_column_width=True)

    st.text('Video Processed')

    output_video = open('output1.mp4','rb')
    out_bytes = output_video.read()
    st.video(out_bytes)

    vid.release()
    out. release()

elif app_mode =='Run on Image':

    drawing_spec = mp_drawing.DrawingSpec(thickness=2, circle_radius=1)

    st.sidebar.markdown('---')

    st.markdown(
    """
    <style>
    [data-testid="stSidebar"][aria-expanded="true"] > div:first-child {
        width: 400px;
    }
    [data-testid="stSidebar"][aria-expanded="false"] > div:first-child {
        width: 400px;
        margin-left: -400px;
    }
    </style>
    """,
    unsafe_allow_html=True,
)
    st.markdown("**Detected Faces**")
    kpi1_text = st.markdown("0")
    st.markdown('---')

    max_faces = st.sidebar.number_input('Maximum Number of Faces', value=2, min_value=1)
    st.sidebar.markdown('---')
    detection_confidence = st.sidebar.slider('Min Detection Confidence', min_value =0.0,max_value = 1.0,value = 0.5)
    st.sidebar.markdown('---')

    img_file_buffer = st.sidebar.file_uploader("Upload an image", type=[ "jpg", "jpeg",'png'])

    if img_file_buffer is not None:
        image = np.array(Image.open(img_file_buffer))

    else:
        demo_image = DEMO_IMAGE
        image = np.array(Image.open(demo_image))

    st.sidebar.text('Original Image')
    st.sidebar.image(image)
    face_count = 0
    # Dashboard
    with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=max_faces,
    min_detection_confidence=detection_confidence) as face_mesh:

        results = face_mesh.process(image)
        out_image = image.copy()

        for face_landmarks in results.multi_face_landmarks:
            face_count += 1

            #print('face_landmarks:', face_landmarks)

            mp_drawing.draw_landmarks(
            image=out_image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACE_CONNECTIONS,
            landmark_drawing_spec=drawing_spec,
            connection_drawing_spec=drawing_spec)
            kpi1_text.write(f"<h1 style='text-align: center; color: red;'>{face_count}</h1>", unsafe_allow_html=True)
        st.subheader('Output Image')
        st.image(out_image,use_column_width= True)
# Watch Tutorial at www.augmentedstartups.info/YouTube
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12260\935291740.py in <module>
#       2 #Face Landmark User Interface with StreamLit
#       3 #Watch Computer Vision Tutorials at www.augmentedstartups.info/YouTube
# ----> 4 import streamlit as st
#       5 import mediapipe as mp
#       6 import cv2
#
# ModuleNotFoundError: No module named 'streamlit'
