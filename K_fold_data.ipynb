# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# from sklearn.model_selection import StratifiedKFold

# %%
DATA_PATH = os.path.join('MP_Data')
actions = np.array(['Add','Agree','Approve','Argue','Arrive','Attack','Bite','Boil','Bond','Call','Cancel','Confrim','Delay','Destroy', 'Die','Draw','Drink','Dance','Deal','Dress', 'Explain','Easy','Fan','Fall','Fight','Fix','Find','Fly','Gather','Hug','Hello' , 'howAreYou' ,'Help','Hit','Hope','Injured','I','Irritate','Insult' ,'Kiss','Knock','Know','Learn','Laugh','Live','Like','Listen','Lie','Love','Make','Match','Need','Now', 'Power','Stop','Thanks','Try','Want','You'])
label_map = {label:num for num, label in enumerate(actions)}

no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30


sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])
        print(action)
# Out:
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Add
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Agree
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Approve
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Argue
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Arrive
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Attack
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Bite
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Boil
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Bond
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
# Call
#
#  'Argue': 3,
#  'Arrive': 4,
#  'Attack': 5,
#  'Bite': 6,
#  'Boil': 7,
#  'Bond': 8,
#  'Call': 9,
#  'Cancel': 10,
#  'Confrim': 11,
#  'Delay': 12,
#  'Destroy': 13,
#  'Die': 14,
#  'Draw': 15,
#  'Drink': 16,
#  'Dance': 17,
#  'Deal': 18,
#  'Dress': 19,
#  'Explain': 20,
#  'Easy': 21,
#  'Fan': 22,
#  'Fall': 23,
#  'Fight': 24,
#  'Fix': 25,
#  'Find': 26,
#  'Fly': 27,
#  'Gather': 28,
#  'Hug': 29,
#  'Hello': 30,
#  'howAreYou': 31,
#  'Help': 32,
#  'Hit': 33,
#  'Hope': 34,
#  'Injured': 35,
#  'I': 36,
#  'Irritate': 37,
#  'Insult': 38,
#  'Kiss': 39,
#  'Knock': 40,
#  'Know': 41,
#  'Learn': 42,
#  'Laugh': 43,
#  'Live': 44,
#  'Like': 45,
#  'Listen': 46,
#  'Lie': 47,
#  'Love': 48,
#  'Make': 49,
#  'Match': 50,
#  'Need': 51,
#  'Now': 52,
#  'Power': 53,
#  'Stop': 54,
#  'Thanks': 55,
#  'Try': 56,
#  'Want': 57,
#  'You': 58}

# %%
np.array(sequences).shape
# Out:
# (1770, 30, 1662)

# %%
X = np.array(sequences)
X.shape
# Out:
# (1770, 30, 1662)

# %%
y =to_categorical(labels).astype(int)
y.shape
# Out:
# (1770, 59)

# %%
kf = KFold(n_splits=5)
kf.get_n_splits(X)

print(kf)

c=1

for train_index, test_index in kf.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    if c==1:
        model = Sequential()
        model.add(LSTM(32, return_sequences=True, activation='relu', input_shape=(30,1662)))
        model.add(Dropout(0.2))
        # model.add(LSTM(64, return_sequences=True, activation='relu'))
        # model.add(Dropout(0.2))
        model.add(LSTM(64, return_sequences=False, activation='relu'))
        # model.add(Dropout(0.5))
        # model.add(Dense(64, activation='relu'))
        #model.add(Dense(32, activation='relu'))
        model.add(Dense(actions.shape[0], activation='softmax'))
        
        
        
        2
        
        EPOCHS = 100
        checkpoint_filepath = '/tmp/checkpoint'
            
        model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath=checkpoint_filepath,
            save_weights_only=True,
            monitor='val_accuracy',
            mode='max',
            save_best_only=True)

# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
model.fit(epochs=EPOCHS, callbacks=[model_checkpoint_callback])

# The model weights (that are considered the best) are loaded into the model.
model.load_weights(checkpoint_filepath) 
        # For Fold 1; Train Decision Tree Classifier on X_train and Test on X_test
        acc_dt = #test decision tree model
        
        
        
        c = c+1
    elif c==2:
        # train SVM with X_train 
        acc_svm= # test svm in X_test'
        c = C+1
    elif c==3:
        
        #train Naive Bayes mode
        acc_nb = #test your model on X_test
        c = C+1
    else:
        # tain KNN model on X_train
        acc_knn = #test model on X_test

# %%
model.compile(loss=..., optimizer=...,
              metrics=['accuracy'])

EPOCHS = 10
checkpoint_filepath = '/tmp/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# Model weights are saved at the end of every epoch, if it's the best seen
# so far.
model.fit(epochs=EPOCHS, callbacks=[model_checkpoint_callback])

# The model weights (that are considered the best) are loaded into the model.
model.load_weights(checkpoint_filepath)

# %%
def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)

# %%
folds = StratifiedKFold(n_splits=3)
